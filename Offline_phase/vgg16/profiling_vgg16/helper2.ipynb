# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
layer_ex = np.genfromtxt('./single_layer_average_profile_vgg_for_percentage.csv', delimiter=',', skip_header=0)

# %%
def make_heatmap(readings,name):
    plt.imshow(readings, cmap='cividis', interpolation='nearest')
    path='./'+name+'.png'
    plt.colorbar()
    plt.title(name)
    plt.savefig(path)
    plt.close()
    plt.show()
    
make_heatmap(layer_ex,"Demo")

# %%
# Example list
data = [3.2, 1.5, 4.7, 2.3, 5.1, 0.9, 2.8]

# Get the original indices of elements when sorted in ascending order
original_indices = [index for index, _ in sorted(enumerate(data), key=lambda x: x[1])]

# Print the list of original indices
print(original_indices)
# Out:
# [5, 1, 3, 6, 0, 2, 4]

# %%
sorted_cpu_ids=[]

for data in layer_ex:
    original_indices = [index for index, _ in sorted(enumerate(data), key=lambda x: x[1])]
    sorted_cpu_ids.append(original_indices)
    
for j in sorted_cpu_ids:
    print(j)
# Out:
# [14, 19, 9, 11, 12, 13, 4, 16, 1, 10, 20, 5, 6, 3, 22, 18, 8, 23, 17, 15, 2, 21, 7, 0]
# [9, 15, 7, 14, 22, 5, 4, 17, 12, 2, 21, 20, 3, 1, 11, 10, 6, 18, 19, 16, 23, 13, 0, 8]
# [13, 17, 8, 16, 19, 7, 15, 10, 14, 11, 22, 20, 18, 9, 21, 12, 23, 4, 5, 6, 3, 2, 1, 0]
# [4, 10, 9, 17, 21, 8, 16, 23, 5, 2, 3, 11, 20, 22, 15, 7, 13, 19, 18, 1, 12, 6, 14, 0]
# [4, 14, 23, 3, 11, 20, 12, 6, 22, 7, 1, 0, 15, 8, 13, 2, 10, 9, 5, 17, 21, 19, 18, 16]
# [22, 21, 23, 19, 20, 17, 16, 15, 14, 13, 11, 12, 10, 9, 18, 8, 7, 4, 2, 3, 6, 1, 5, 0]
# [5, 4, 21, 6, 19, 9, 2, 17, 20, 10, 15, 16, 12, 3, 7, 14, 1, 18, 11, 22, 23, 13, 8, 0]
# [7, 15, 3, 4, 1, 22, 14, 8, 19, 2, 13, 21, 20, 10, 5, 16, 17, 18, 6, 23, 0, 11, 12, 9]
# [2, 19, 23, 22, 0, 3, 17, 5, 1, 9, 6, 20, 8, 7, 4, 18, 16, 10, 15, 14, 11, 21, 12, 13]
# [22, 23, 21, 20, 17, 19, 16, 14, 15, 13, 18, 10, 9, 8, 7, 5, 4, 6, 11, 12, 3, 2, 1, 0]
# [23, 8, 12, 3, 19, 2, 17, 20, 4, 15, 10, 5, 6, 21, 14, 13, 11, 9, 22, 1, 16, 18, 7, 0]
# [2, 15, 14, 7, 5, 22, 17, 13, 10, 6, 19, 8, 9, 3, 11, 12, 20, 21, 4, 16, 1, 18, 0, 23]
# [7, 11, 2, 4, 17, 1, 14, 10, 20, 18, 22, 3, 23, 16, 15, 9, 19, 13, 8, 12, 6, 21, 5, 0]
# [22, 21, 20, 23, 19, 18, 13, 15, 16, 17, 14, 10, 11, 8, 12, 7, 9, 5, 1, 0, 6, 2, 4, 3]
# [3, 5, 23, 21, 17, 11, 16, 14, 13, 12, 18, 7, 20, 10, 9, 8, 2, 1, 22, 19, 15, 6, 4, 0]
# [11, 17, 19, 21, 7, 18, 22, 5, 20, 16, 9, 14, 15, 23, 8, 1, 13, 3, 2, 4, 10, 6, 12, 0]
# [11, 7, 17, 14, 15, 3, 20, 19, 10, 9, 13, 18, 4, 8, 16, 21, 22, 5, 2, 6, 1, 23, 12, 0]
# [23, 22, 16, 20, 18, 14, 21, 19, 15, 17, 13, 12, 9, 11, 0, 10, 3, 4, 1, 8, 5, 2, 6, 7]
# [17, 14, 19, 21, 22, 16, 15, 20, 23, 18, 13, 10, 12, 11, 8, 9, 7, 6, 5, 4, 3, 2, 1, 0]
# [5, 2, 23, 4, 14, 16, 3, 15, 17, 22, 6, 12, 1, 9, 13, 10, 7, 8, 20, 21, 11, 18, 19, 0]
# [14, 9, 10, 23, 7, 11, 8, 21, 20, 15, 17, 1, 3, 4, 16, 6, 19, 5, 22, 2, 13, 12, 18, 0]
# [10, 11, 8, 16, 9, 7, 13, 5, 12, 3, 17, 20, 21, 14, 18, 19, 4, 6, 15, 2, 1, 22, 23, 0]

# %%
import pickle

with open('vgg_naive_cpuProfiling_mappings.pkl', 'wb') as file:
    pickle.dump(sorted_cpu_ids, file)

# %%
with open('vgg_naive_cpuProfiling_mappings.pkl', 'rb') as file:
        vgg_naive_profile = pickle.load(file)

# %%
for j in vgg_naive_profile:
    print(j)
# Out:
# [14, 19, 9, 11, 12, 13, 4, 16, 1, 10, 20, 5, 6, 3, 22, 18, 8, 23, 17, 15, 2, 21, 7, 0]
# [9, 15, 7, 14, 22, 5, 4, 17, 12, 2, 21, 20, 3, 1, 11, 10, 6, 18, 19, 16, 23, 13, 0, 8]
# [13, 17, 8, 16, 19, 7, 15, 10, 14, 11, 22, 20, 18, 9, 21, 12, 23, 4, 5, 6, 3, 2, 1, 0]
# [4, 10, 9, 17, 21, 8, 16, 23, 5, 2, 3, 11, 20, 22, 15, 7, 13, 19, 18, 1, 12, 6, 14, 0]
# [4, 14, 23, 3, 11, 20, 12, 6, 22, 7, 1, 0, 15, 8, 13, 2, 10, 9, 5, 17, 21, 19, 18, 16]
